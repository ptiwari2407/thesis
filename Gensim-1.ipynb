# %%
import gensim.downloader as api
# api.info('word2vec-google-news-300')
wv=api.load('word2vec-google-news-300')

# %%
# existing word embeddings and words they generate in terms of semantic similarity

# %%
wv.most_similar('able')
# Out:
# [('unable', 0.6783158779144287),
#  ('ableto', 0.6157487630844116),
#  ('trying', 0.5668547749519348),
#  ('can', 0.5651538968086243),
#  ('allowed', 0.5598537921905518),
#  ('managed', 0.5453858375549316),
#  ('enough', 0.5436093807220459),
#  ('ability', 0.533251941204071),
#  ('could', 0.5249689817428589),
#  ('going', 0.5218186974525452)]

# %%
from nltk.corpus import wordnet as wn

# %%
# this block is strictly reserved for software development of this project
word = 'dog'
syn_group = []
syn_dict = dict()
for elem in wn.synsets(word,pos='n'):
    syn_group.append(elem.name())
    print(elem)
for elem in syn_group:
    syn_dict[elem]= wn.synset(elem).lemma_names()
#     print(elem.hypernyms())
    print(elem,syn_dict[elem])
    
for elem in syn_group:
    print(elem, wn.synset(elem).lemma_names())
    
#     syn_dict[elem]= wn.synset(elem).lemma_names()
#     print(wn.synset(elem).lemma_names())
# #     print(wn.synset(elem).definition())
#     print(elem)
print(syn_group)
# Out:
# Synset('dog.n.01')
# Synset('frump.n.01')
# Synset('dog.n.03')
# Synset('cad.n.01')
# Synset('frank.n.02')
# Synset('pawl.n.01')
# Synset('andiron.n.01')
# dog.n.01 ['dog', 'domestic_dog', 'Canis_familiaris']
# frump.n.01 ['frump', 'dog']
# dog.n.03 ['dog']
# cad.n.01 ['cad', 'bounder', 'blackguard', 'dog', 'hound', 'heel']
# frank.n.02 ['frank', 'frankfurter', 'hotdog', 'hot_dog', 'dog', 'wiener', 'wienerwurst', 'weenie']
# pawl.n.01 ['pawl', 'detent', 'click', 'dog']
# andiron.n.01 ['andiron', 'firedog', 'dog', 'dog-iron']
# dog.n.01 ['dog', 'domestic_dog', 'Canis_familiaris']
# frump.n.01 ['frump', 'dog']
# dog.n.03 ['dog']
# cad.n.01 ['cad', 'bounder', 'blackguard', 'dog', 'hound', 'heel']
# frank.n.02 ['frank', 'frankfurter', 'hotdog', 'hot_dog', 'dog', 'wiener', 'wienerwurst', 'weenie']
# pawl.n.01 ['pawl', 'detent', 'click', 'dog']
# andiron.n.01 ['andiron', 'firedog', 'dog', 'dog-iron']
# ['dog.n.01', 'frump.n.01', 'dog.n.03', 'cad.n.01', 'frank.n.02', 'pawl.n.01', 'andiron.n.01']

# %%
dog = wn.synset('living_thing.n.01')
hypo = lambda s: s.hyponyms()
hyper = lambda s: s.hypernyms()
# print(len(list(set(dog.closure(hypo, depth=20)))))
# print(len(list(dog.closure(hyper, depth=20))))
# print(list(dog.closure(hypo, depth=20)))
# print(list(dog.closure(hyper, depth=2)))
dog
# Out:
# Synset('living_thing.n.01')

# %%
q=list(dog.closure(hyper, depth=1))
for elem in q:
    elem = elem.name()
    name = wn.synset(elem)
    a = list(set(dog.closure(hypo, depth=20)))
    print(elem,a)
# Out:
# whole.n.02 [Synset('publican.n.01'), Synset('jungle_hen.n.01'), Synset('water_vole.n.02'), Synset('bugloss.n.01'), Synset('bengali.n.01'), Synset('myxosporidian.n.01'), Synset('zuni.n.01'), Synset('shield_fern.n.01'), Synset('american_staffordshire_terrier.n.01'), Synset('deaconess.n.01'), Synset('suricate.n.01'), Synset('sugar_daddy.n.01'), Synset('four-lined_plant_bug.n.01'), Synset('dietician.n.01'), Synset('jack-in-the-pulpit.n.01'), Synset('snuffer.n.03'), Synset('dinocerate.n.01'), Synset('ponce_de_leon.n.01'), Synset('copepod.n.01'), Synset('forget-me-not.n.01'), Synset('ailanthus_silkworm.n.01'), Synset('hispid_pocket_mouse.n.01'), Synset('tiger_cowrie.n.01'), Synset('carabao.n.01'), Synset('ivory_tree.n.01'), Synset('actinomycete.n.01'), Synset('pluralist.n.02'), Synset('love-in-a-mist.n.03'), Synset('conveyer.n.01'), Synset('north_island_edelweiss.n.01'), Synset('tomboy.n.01'), Synset('eastern_kingbird.n.01'), Synset('name_dropper.n.01'), Synset('striped_skunk.n.01'), Synset('winter_aconite.n.01'), Synset('dervish.n.01'), Synset('frogmouth.n.01'), Synset('defaulter.n.02'), Synset('smooth_sumac.n.01'), Synset('earl_marshal.n.01'), Synset('abuser.n.01'), Synset('cub_scout.n.01'), Synset('murder_suspect.n.01'), Synset('monster.n.04'), Synset('climber.n.01'), Synset('bank_manager.n.01'), Synset('nan.n.01'), Synset('broom_beard_grass.n.01'), Synset('skin_cell.n.01'), Synset('francisella.n.01'), Synset('anglophile.n.01'), Synset('salsify.n.02'), Synset('arenaviridae.n.01'), Synset('queen's_cup.n.01'), Synset('american_cranberry.n.01'), Synset('special_agent.n.01'), Synset('oleander_fern.n.01'), Synset('bigeye_scad.n.01'), Synset('wood_ant.n.01'), Synset('ottawa.n.01'), Synset('evaluator.n.01'), Synset('bailee.n.01'), Synset('celibate.n.01'), Synset('perch.n.07'), Synset('quechua.n.01'), Synset('abator.n.01'), Synset('blue_pea.n.01'), Synset('tropical_prawn.n.01'), Synset('cock's_eggs.n.01'), Synset('emu.n.02'), Synset('bay_stater.n.01'), Synset('geezer.n.01'), Synset('archpriest.n.01'), Synset('purveyor.n.01'), Synset('ox.n.02'), Synset('siris.n.01'), Synset('pothead.n.01'), Synset('crammer.n.01'), Synset('old_world_quail.n.01'), Synset('cloudberry.n.01'), Synset('astrologer.n.01'), Synset('bird_of_paradise.n.03'), Synset('mennonite.n.01'), Synset('balsam_woolly_aphid.n.01'), Synset('banksia.n.01'), Synset('devilwood.n.01'), Synset('coronilla.n.01'), Synset('double_agent.n.01'), Synset('common_european_jay.n.01'), Synset('manatee.n.01'), Synset('schoolmaster.n.03'), Synset('rose_geranium.n.01'), Synset('laminator.n.01'), Synset('wild_sarsaparilla.n.01'), Synset('ozark_chinkapin.n.01'), Synset('spike_lavender.n.01'), Synset('affiant.n.01'), Synset('authoritarian.n.01'), Synset('encyclopedist.n.01'), Synset('dwarf_sperm_whale.n.01'), Synset('browser.n.01'), Synset('existentialist.n.01'), Synset('dairyman.n.02'), Synset('traveler's_joy.n.01'), Synset('rotavirus.n.01'), Synset('multiflora.n.01'), Synset('bristly_sarsaparilla.n.01'), Synset('red_grouse.n.01'), Synset('folk_dancer.n.01'), Synset('lesser_wintergreen.n.01'), Synset('burrawong.n.01'), Synset('atlantic_cod.n.01'), Synset('crimp.n.02'), Synset('calabar-bean_vine.n.01'), Synset('japanese_spaniel.n.01'), Synset('wobbly.n.01'), Synset('millipede.n.01'), Synset('probationer.n.02'), Synset('coyote.n.03'), Synset('watermelon.n.01'), Synset('tennessee_walker.n.01'), Synset('percher.n.01'), Synset('bovid.n.01'), Synset('viceroy.n.01'), Synset('yellow_jacket.n.02'), Synset('gazania.n.01'), Synset('cambodian.n.01'), Synset('crop.n.02'), Synset('consumer.n.01'), Synset('american_red_squirrel.n.01'), Synset('chief_of_staff.n.01'), Synset('chambered_nautilus.n.01'), Synset('marlberry.n.01'), Synset('caltrop.n.01'), Synset('southern_dewberry.n.01'), Synset('wonder_woman.n.01'), Synset('sensitive_plant.n.01'), Synset('receiver.n.06'), Synset('canada_wild_rye.n.01'), Synset('water_hickory.n.01'), Synset('one_of_the_boys.n.01'), Synset('councilwoman.n.01'), Synset('giant_star_grass.n ...

# %%
for elem in syn_group:
    print(elem, wn.synset(elem).lemma_names())
# Out:
# dog.n.01 ['dog', 'domestic_dog', 'Canis_familiaris']
# frump.n.01 ['frump', 'dog']
# dog.n.03 ['dog']
# cad.n.01 ['cad', 'bounder', 'blackguard', 'dog', 'hound', 'heel']
# frank.n.02 ['frank', 'frankfurter', 'hotdog', 'hot_dog', 'dog', 'wiener', 'wienerwurst', 'weenie']
# pawl.n.01 ['pawl', 'detent', 'click', 'dog']
# andiron.n.01 ['andiron', 'firedog', 'dog', 'dog-iron']

# %%
word = wn.synset('archeologist.n.01')
hyper_word = set([i for i in word.closure(lambda s:s.hypernyms())])
hypo_word = set([i for i in word.closure(lambda s:s.hyponyms())])
print(list(hyper_word)[3].lemma_names())
# print(list(hyper_word))
print(len(list(hyper_word)))
print(len(list(hypo_word)))
for i in range(len(list(hyper_word))):
    print(list(hyper_word)[i].lemma_names(),list(hyper_word)[i])
# Out:
# ['object', 'physical_object']
# 11
# 3
# ['scientist'] Synset('scientist.n.01')
# ['organism', 'being'] Synset('organism.n.01')
# ['physical_entity'] Synset('physical_entity.n.01')
# ['object', 'physical_object'] Synset('object.n.01')
# ['living_thing', 'animate_thing'] Synset('living_thing.n.01')
# ['causal_agent', 'cause', 'causal_agency'] Synset('causal_agent.n.01')
# ['whole', 'unit'] Synset('whole.n.02')
# ['entity'] Synset('entity.n.01')
# ['person', 'individual', 'someone', 'somebody', 'mortal', 'soul'] Synset('person.n.01')
# ['anthropologist'] Synset('anthropologist.n.01')
# ['social_scientist'] Synset('social_scientist.n.01')

# %%
m = d['a']
q=[]

def unlist(m):
    q = []
    for x in m:
        if(type(x) is list):
            for y in x:
                q.append(y)
            continue
        q.append(x)
    return q
q = unlist(m) 
    
print(q)

# %%
word = wn.synset('frump.n.01')
hyper_word = set([i for i in word.closure(lambda s:s.hypernyms())])
hypo_word = set([i for i in word.closure(lambda s:s.hyponyms())])
# print(list(hyper_word)[3].lemma_names())
# print(list(hyper_word))
print((list(hyper_word)))
print((list(hypo_word)))
# Out:
# [Synset('whole.n.02'), Synset('physical_entity.n.01'), Synset('object.n.01'), Synset('unpleasant_person.n.01'), Synset('person.n.01'), Synset('organism.n.01'), Synset('living_thing.n.01'), Synset('entity.n.01'), Synset('unwelcome_person.n.01'), Synset('unpleasant_woman.n.01'), Synset('causal_agent.n.01')]
# []

# %%
for i in range(10):
    print(list(hypo_word)[i].lemma_names(),list(hypo_word)[i])
# Out:
# ['wolfhound'] Synset('wolfhound.n.01')
# ['Scotch_terrier', 'Scottish_terrier', 'Scottie'] Synset('scotch_terrier.n.01')
# ['Manchester_terrier', 'black-and-tan_terrier'] Synset('manchester_terrier.n.01')
# ['vizsla', 'Hungarian_pointer'] Synset('vizsla.n.01')
# ['spaniel'] Synset('spaniel.n.01')
# ['Airedale', 'Airedale_terrier'] Synset('airedale.n.01')
# ['sporting_dog', 'gun_dog'] Synset('sporting_dog.n.01')
# ['bluetick'] Synset('bluetick.n.01')
# ['Dandie_Dinmont', 'Dandie_Dinmont_terrier'] Synset('dandie_dinmont.n.01')
# ['Siberian_husky'] Synset('siberian_husky.n.01')

# %%
# for item in hyper_word:
#     print(item.hyponyms())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-99-c1254f49ecdd> in <module>
#       1 # for item in hyper_word:
#       2 #     print(item.hyponyms())
# ----> 3 word.lemma()
#
# AttributeError: 'Synset' object has no attribute 'lemma'

# %%
x=list(hyper_word)[0]
print(list(x.hyponyms()), x.lemma_names())
# Out:
# [Synset('bag.n.07'), Synset('cow.n.03'), Synset('dragon.n.02'), Synset('frump.n.01'), Synset('she-devil.n.01'), Synset('shrew.n.01'), Synset('vixen.n.01')] ['unpleasant_woman', 'disagreeable_woman']

# %%
x=(list(hyper_word)[0].lemma_names())
print(x)
# for item in x:
#     print(x.hyponyms())
# Out:
# ['unpleasant_woman', 'disagreeable_woman']

# %%
w1 = wn.synset('living_thing.n.01')
x =[]
for l in w1.lemmas():
    print(l.name())
    x.append(l.name())
    if (l.antonyms()):
        x.append(l.antonyms()[0].name())
print(x)
print(w1)
# Out:
# living_thing
# animate_thing
# ['living_thing', 'animate_thing']
# Synset('living_thing.n.01')

# %%
word = 'termagant'
syn_group = []
syn_dict = dict()
for elem in wn.synsets(word):
    syn_group.append(elem.name())
    print(elem)
for elem in syn_group:
    syn_dict[elem]= wn.synset(elem).definition()
#     print(elem.hypernyms())
    print(elem,syn_dict[elem])
# Out:
# Synset('shrew.n.01')
# shrew.n.01 a scolding nagging bad-tempered woman

# %%
# for i in wn.all_synsets():
#     if i.pos() in ['a','s']:
#         for j in i.lemmas():
#             if j.antonyms():
#                 print(j.name(), j.antonyms[0].name())

# %%
# wv.most_similar('termagant')+wv.most_similar('frumps')
wv.most_similar('she-devil')
# wv.most_similar('baron')
# wv.most_similar('magnate')
# wv.most_similar('tycoon')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-102-a4408c79d253> in <module>
#       1 # wv.most_similar('termagant')+wv.most_similar('frumps')
# ----> 2 wv.most_similar('she-devil')
#       3 # wv.most_similar('baron')
#       4 # wv.most_similar('magnate')
#       5 # wv.most_similar('tycoon')
#
# ~\Anaconda3\envs\epic_jenoptik_venv\lib\site-packages\gensim\models\keyedvectors.py in most_similar(self, positive, negative, topn, restrict_vocab, indexer)
#     551                 mean.append(weight * word)
#     552             else:
# --> 553                 mean.append(weight * self.word_vec(word, use_norm=True))
#     554                 if word in self.vocab:
#     555                     all_words.add(self.vocab[word].index)
#
# ~\Anaconda3\envs\epic_jenoptik_venv\lib\site-packages\gensim\models\keyedvectors.py in word_vec(self, word, use_norm)
#     466             return result
#     467         else:
# --> 468             raise KeyError("word '%s' not in vocabulary" % word)
#     469
#     470     def get_vector(self, word):
#
# KeyError: "word 'she-devil' not in vocabulary"

# %%
# working with adjective here

# %%
word = 'worse'
syn_group = []
syn_dict = dict()
for elem in wn.synsets(word,pos=['s','a']):
    syn_group.append(elem.name())
    print(elem)
# for elem in syn_group:
#     syn_dict[elem]= wn.synset(elem).definition()
# #     print(elem.hypernyms())
#     print(elem,syn_dict[elem])
# Out:
# Synset('worse.a.01')
# Synset('worse.a.02')
# Synset('bad.a.01')
# Synset('bad.s.02')
# Synset('bad.s.03')
# Synset('bad.s.04')
# Synset('regretful.a.01')
# Synset('bad.s.06')
# Synset('bad.s.07')
# Synset('bad.s.08')
# Synset('bad.s.09')
# Synset('bad.s.10')
# Synset('bad.s.11')
# Synset('bad.s.12')
# Synset('bad.s.13')
# Synset('bad.s.14')
# Synset('worse.a.01')
# Synset('worse.a.02')
# Synset('bad.a.01')
# Synset('bad.s.02')
# Synset('bad.s.03')
# Synset('bad.s.04')
# Synset('regretful.a.01')
# Synset('bad.s.06')
# Synset('bad.s.07')
# Synset('bad.s.08')
# Synset('bad.s.09')
# Synset('bad.s.10')
# Synset('bad.s.11')
# Synset('bad.s.12')
# Synset('bad.s.13')
# Synset('bad.s.14')

# %%
word = wn.synset('bad.s.11')
hyper_word = set([i for i in word.closure(lambda s:s.hypernyms())])
hypo_word = set([i for i in word.closure(lambda s:s.hyponyms())])
print(list(hyper_word))
print(list(hypo_word))
# Out:
# []
# []

# %%
syn=[]
ant =[]

for synset in wn.synsets('worse'):
    for lemma in synset.lemmas():
        syn.append(lemma.name())
        if lemma.antonyms():
            ant.append(lemma.antonyms()[0].name())

print(syn)
print(ant)
# Out:
# ['worse', 'worse', 'worse', 'worsened', 'bad', 'bad', 'big', 'bad', 'tough', 'bad', 'spoiled', 'spoilt', 'regretful', 'sorry', 'bad', 'bad', 'uncollectible', 'bad', 'bad', 'bad', 'risky', 'high-risk', 'speculative', 'bad', 'unfit', 'unsound', 'bad', 'bad', 'bad', 'forged', 'bad', 'defective', 'worse']
# ['better', 'better', 'good', 'unregretful']

# %%
# average possible number of meanings in verb category

num_meanings_per_adj = []

# %%
# wv.most_similar('king')+wv.most_similar('queen')+wv.most_similar('bishop')+wv.most_similar('rook')

# %%
# wv.most_similar(mean(wv(‘baron’)+wv(‘magnate’)+wv(‘tycoon’)))
common=wv.wv['baron']+wv.wv['tycoon']+wv.wv['magnate']
common

result = wv.most_similar(positive=['baron','magnate','tycoon'])
# result_chess = result = wv.most_similar(positive=['king','bishop','rook'])

# %%
result
# result_chess

# %%
for elem in syn_dict:
    if len(syn_dict[elem])<2:
        del syn_dict[elem]
for elem in syn_dict:
    print(elem, syn_dict[elem])
    print(type(syn_dict[elem]))

# %%
syn = wn.synset('king.n.09').hypernyms()[0].hyponyms()
# syn.hypernyms()[0].hyponyms()
syn

# %%
wv.most_similar()

# %%
syn = wn.synsets('king')[0]
print(syn.name(), syn.definition())
# syn.lemmas()
for ele in syn.hypernyms():
    print(ele.hyponyms())

# %%
wn.synsets('king')

# %%
wn.synset('baron.n.03').definition()

# %%
wn.synset('baron.n.03').lemma_names()

# %%
# syn.hypernym_paths()

# %%
syn = wn.synsets('great')[0]
syn.hypernyms()[0].hyponyms()

# %%
s =[]
for syn in wn.synsets('great'):
    z=[]
    print(syn.name(), syn.hypernyms())
    z.append(syn.hypernyms())
    s.append(z)
for ele in s:
    print(ele)

# %%
s=[]
s_h =[]

for syn in wn.synsets('King'):
    s.append(syn.name())
    sh_append()
    
for e in s:
    print(e)

# %%
s =[]
count = 0
for syn in wn.synsets('king'):
    s.append(syn.lemmas())
for ele in s:
    count+=1
    print(ele)
    print(count)

# %%
synonyms = []
antonyms = []

for syn in wn.synsets("king"):
    for l in syn.lemmas():
        synonyms.append(l.name())
        if l.antonyms():
            antonyms.append(l.antonyms()[0].name())

print(set(synonyms))

# %%
print(set(antonyms))
